# %%
import os
from datetime import datetime
import time
import pyaudio
import librosa
import asyncio
import threading
import numpy as np
from transformers import AutoProcessor, AutoTokenizer, MarianMTModel, MarianTokenizer, AutoModelForSpeechSeq2Seq, pipeline
import spacy
from spellchecker import SpellChecker

import torch
import torchaudio
import tensorflow

# %%
class AudioChanel():
    def __init__(self):
        #change this according to your model
        self.chunk = 1024
        self.format = pyaudio.paInt16
        self.channels = 1#2
        self.rate = 16000
        self.recorder = pyaudio.PyAudio()
        self.frames = []
        self.seconds = 2
        # Открыть поток для записи
        #1 {'index': 1, 'structVersion': 2, 'name': 'Line 1 (Virtual Audio Cable)', 'hostApi': 0, 'maxInputChannels': 2, 
        #   'maxOutputChannels': 0, 'defaultLowInputLatency': 0.09, 'defaultLowOutputLatency': 0.09, 
        #   'defaultHighInputLatency': 0.18, 'defaultHighOutputLatency': 0.18, 'defaultSampleRate': 44100.0}
        self.input_stream = self.recorder.open(format=self.format,
                                          channels=self.channels,
                                          rate=self.rate,
                                          input=True,
                                          frames_per_buffer=self.chunk,
                                          input_device_index=1) #0,1 - work
        # Открыть поток для воспроизведения
        #5 {'index': 5, 'structVersion': 2, 'name': '... (Realtek)', 'hostApi': 0, 'maxInputChannels': 0, 
        #   'maxOutputChannels': 2, 'defaultLowInputLatency': 0.09, 'defaultLowOutputLatency': 0.09, 
        #   'defaultHighInputLatency': 0.18, 'defaultHighOutputLatency': 0.18, 'defaultSampleRate': 44100.0}
        self.output_stream = self.recorder.open(format=self.format,
                                           channels=self.channels,
                                           rate=self.rate,
                                           output=True,
                                           frames_per_buffer=self.chunk,
                                           input_device_index=5) #5- work
        
        
    def record(self):
        while True:
            data = self.input_stream.read(self.chunk)
            self.frames.append(data)

    def play(self, audio = None):
        output_stream = self.recorder.open(format=self.format,
                                           channels=self.channels,
                                           rate=self.rate,
                                           output=True,
                                           frames_per_buffer=self.chunk,
                                           input_device_index=5) #5- work
        match audio:
            case list():
                for frame in audio:
                    output_stream.write(frame)
            case _:
                output_stream.write(audio.tobytes())

    def play_default(self):
        output_stream = self.recorder.open(format=self.format,
                                           channels=self.channels,
                                           rate=self.rate,
                                           output=True,
                                           frames_per_buffer=self.chunk,
                                           input_device_index=5) #5- work
        with threading.Lock():
            to_play = list(self.frames)
        for frame in to_play:
            output_stream.write(frame)
    
    def get(self):
        with threading.Lock():
            return list(self.frames)
        
        
    def close(self):
        self.input_stream.stop_stream()
        self.input_stream.close()

# %%
class Agent():
    def __init__(self):
        self.audio = AudioChanel()
        self.device = torch.device('cuda')

        whisper_name = "openai/whisper-large-v3"
        self.model = AutoModelForSpeechSeq2Seq.from_pretrained(
            whisper_name, torch_dtype=torch.float, low_cpu_mem_usage=True, use_safetensors=True)
        self.model.to(self.device)
        self.processor = AutoProcessor.from_pretrained(whisper_name)
        self.pipe = pipeline(
            "automatic-speech-recognition",
            model=self.model,
            tokenizer=self.processor.tokenizer,
            feature_extractor=self.processor.feature_extractor,
            max_new_tokens=128,
            chunk_length_s=30,
            batch_size=16,
            return_timestamps=True,
            torch_dtype=torch.float,
            device=self.device,
        )
        self.PASS_VAR = False

        model_name = "Helsinki-NLP/opus-mt-en-ru"
        self.tokenizer_translate = MarianTokenizer.from_pretrained(model_name)
        self.model_translate = MarianMTModel.from_pretrained(model_name)
        self.model_translate.to(self.device)
        
        language = 'ru'
        model_id = 'v4_ru'
        self.sample_rate = 48000
        self.speaker = 'kseniya'
        
        self.model_voice, _ = torch.hub.load(repo_or_dir='snakers4/silero-models',
                                             model='silero_tts',
                                             language=language,
                                             speaker=model_id)
        self.model_voice.to(self.device)
        self.to_play = []

    def send_to_play(self):
        while True:
            time.sleep(1)
            with threading.Lock():
                copy_to_play = list(self.to_play)
            while len(copy_to_play):
                to_play = copy_to_play[0]
                translation = threading.Thread(target=self.audio.play,args=(to_play[0],))
                original = threading.Thread(target=self.audio.play,args=(to_play[1],))
                
                translation.start()
                original.start()
                
                translation.join()
                original.join()
                with threading.Lock():
                    del self.to_play[0]
                    del copy_to_play[0]
    
    async def run(self):
        #start recording
        _ = threading.Thread(target=self.audio.record).start()
        _ = threading.Thread(target=self.send_to_play).start()
        
        await asyncio.sleep(5)
        last_state = ''
        while True:
            '''
            PART 1
            RECORDING
            description: record every 2 seconds of audio from PC
            '''
            # await asyncio.sleep(2) for very fast pc
            time = datetime.now()
            frames = self.audio.get()[:80]##200 - default, 100 - boost speed
            to_model = np.frombuffer(b''.join(frames), dtype=np.int16)
            end_1 = datetime.now()
            if not len(frames):
                continue
            print('end_1: ', end_1-time)
            '''
            PART 2
            CONVERTING AUDIO TO FULL TEXT TEXT
            description: put audio into model and get recognized words
            '''
            whisper_result = self.pipe(to_model)['chunks']#  'chunks': [{'timestamp': (0.0, 19.94), 'text': ' Undertexter av Nicolai Winther'}]}
            if last_state == '':
                last_state = whisper_result[0]['text']
            else:
                if last_state == whisper_result[0]['text']:
                    self.PASS_VAR = True
                last_state = whisper_result[0]['text']
            print(whisper_result)
            end_2 = datetime.now()
            print('end_2: ', end_2-end_1)
            '''
            PART 3
            TRANSLATE SENTENCE INTO RUSSIAN (or any other language)
            description: translate one of the list, because we should be sure about full context
            '''
            if len(whisper_result)<=1 and not self.PASS_VAR:
                continue
            self.PASS_VAR = False
            print(whisper_result)
            
            prefix = 'translate to ru: '
            ### delete part of audio.frames list
            with threading.Lock():
                to_del = int(whisper_result[0]['timestamp'][1]*self.audio.rate/self.audio.chunk)
                play_background = self.audio.frames[:to_del]#to_del+1
                del self.audio.frames[:to_del]
            ###
            src_text = prefix + whisper_result[0]['text']
            
            # translate Englosh to Russian
            input_ids = self.tokenizer_translate(src_text, return_tensors="pt")
            
            generated_tokens = self.model_translate.generate(**input_ids.to(self.device))
            
            result = self.tokenizer_translate.batch_decode(generated_tokens, skip_special_tokens=True)
            end_3 = datetime.now()
            print('end_3: ', end_3-end_2)
            '''
            PART 4
            VOICEOVER OF TEXT AND PLAY
            description: voice translated text
            '''
            print(result[0])
            text_to_translate = str(result[0])
            while 'Перевод на ru:' in text_to_translate:
                text_to_translate.replace('Перевод на ru: ','')
            if not len(text_to_translate):
                continue

            #errors just happens sometimes, don't know why
            try:
                audio = self.model_voice.apply_tts(text=text_to_translate,
                            speaker=self.speaker,
                            sample_rate=self.sample_rate)
            except:
                continue
            
            audio_numpy = audio.cpu().numpy()
            audio_resampled = librosa.resample(audio_numpy, orig_sr=self.sample_rate, 
                                               target_sr=self.audio.rate, res_typestr='fft')
            audio_int16 = (audio_resampled * 32767).astype(np.int16)
            end_4 = datetime.now()
            print('end_4: ', end_4-end_3)
            # self.audio.play(audio_int16)
            with threading.Lock():
                self.to_play.append((audio_int16,frames[:to_del]))
            # _ = threading.Thread(target=self.audio.play, args=(play_background,)).start()
            
a = Agent()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# E:\anaconda\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Using cache found in C:\Users\User/.cache\torch\hub\snakers4_silero-models_master

# %%
await a.run()
# Out:
# end_1:  0:00:00
# E:\anaconda\Lib\site-packages\transformers\models\whisper\modeling_whisper.py:691: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# [{'timestamp': (0.0, 2.26), 'text': ' We have to do, you know, what are you looking for?'}, {'timestamp': (2.58, 5.12), 'text': ' And being the Socratic professor that I am, well, what?'}]
# end_2:  0:00:41.589966
# [{'timestamp': (0.0, 2.26), 'text': ' We have to do, you know, what are you looking for?'}, {'timestamp': (2.58, 5.12), 'text': ' And being the Socratic professor that I am, well, what?'}]
# end_3:  0:00:01.549622
# Переведи на ru: Мы должны сделать, знаешь, что ты ищешь?
# end_4:  0:00:08.154352
# end_1:  0:00:00
# [{'timestamp': (0.0, 2.22), 'text': ' and being the Socratic professor that I am,'}, {'timestamp': (2.22, 4.06), 'text': ' I was like, well, what does your son or daughter do?'}, {'timestamp': (4.12, 5.06), 'text': ' What do they do really well?'}]
# end_2:  0:00:41.200716
# [{'timestamp': (0.0, 2.22), 'text': ' and being the Socratic professor that I am,'}, {'timestamp': (2.22, 4.06), 'text': ' I was like, well, what does your son or daughter do?'}, {'timestamp': (4.12, 5.06), 'text': ' What do they do really well?'}]
# end_3:  0:00:01.271944
# Перевод на ru: и будучи Сократическим профессором,
# end_4:  0:00:13.945624
# end_1:  0:00:00
# [{'timestamp': (0.0, 1.88), 'text': ' well, what does your son or daughter do?'}, {'timestamp': (1.94, 4.38), 'text': " What do they do really well that we'd be interested in?"}]
# end_2:  0:00:34.131098
# [{'timestamp': (0.0, 1.88), 'text': ' well, what does your son or daughter do?'}, {'timestamp': (1.94, 4.38), 'text': " What do they do really well that we'd be interested in?"}]
# end_3:  0:00:01.178745
# Перевод на ru: Что делает ваш сын или дочь?
# end_4:  0:00:04.548561
# end_1:  0:00:00
# [{'timestamp': (0.0, 2.44), 'text': " What do they do really well that we'd be interested in?"}, {'timestamp': (3.04, 5.18), 'text': " And typically their answers are, well, they've got great..."}]
# end_2:  0:00:35.770123
# [{'timestamp': (0.0, 2.44), 'text': " What do they do really well that we'd be interested in?"}, {'timestamp': (3.04, 5.18), 'text': " And typically their answers are, well, they've got great..."}]
# end_3:  0:00:01.347020
# Перевод на ru: Что они делают на самом деле хорошо, что нас интересует?
# end_4:  0:00:05.642375
# end_1:  0:00:00
# [{'timestamp': (0.0, 5.12), 'text': " And typically their answers are, well they've got great vision, they're really good, they can see the entire field."}]
# end_2:  0:00:34.344100
# end_1:  0:00:00.000752
# [{'timestamp': (0.0, 5.12), 'text': " And typically their answers are, well they've got great vision, they're really good, they can see the entire field."}]
# end_2:  0:00:34.251810
# [{'timestamp': (0.0, 5.12), 'text': " And typically their answers are, well they've got great vision, they're really good, they can see the entire field."}]
# end_3:  0:00:02.118121
# И, как правило, их ответы: у них отличное видение, они действительно хороши, они могут видеть все поле.
# end_4:  0:00:02.027658
# end_1:  0:00:00
# [{'timestamp': (0.0, 5.1), 'text': " or my daughter is the fastest player there's nobody that can beat her or my son's"}]
# end_2:  0:00:29.877217
# end_1:  0:00:00
# [{'timestamp': (0.0, 5.1), 'text': " or my daughter is the fastest player there's nobody that can beat her or my son's"}]
# end_2:  0:00:29.841695
# [{'timestamp': (0.0, 5.1), 'text': " or my daughter is the fastest player there's nobody that can beat her or my son's"}]
# end_3:  0:00:01.773527
# Перевод на ru: или моя дочь - самый быстрый игрок, никто не сможет победить ее или моего сына.
# end_4:  0:00:01.382045
# end_1:  0:00:00
# [{'timestamp': (0.0, 3.56), 'text': ' got a great left foot or really, really great in the air and can hit every ball.'}, {'timestamp': (4.24, 5.02), 'text': " I'm like, yeah."}]
# end_2:  0:00:35.000230
# [{'timestamp': (0.0, 3.56), 'text': ' got a great left foot or really, really great in the air and can hit every ball.'}, {'timestamp': (4.24, 5.02), 'text': " I'm like, yeah."}]
# end_3:  0:00:02.449944
# Перевод на ru: имеет отличную левую ногу или очень, очень хорошо в воздухе и может ударить по каждому мячу.
# end_4:  0:00:01.599372
# end_1:  0:00:00
# [{'timestamp': (0.0, 2.66), 'text': " I'm like, yeah, not bad."}, {'timestamp': (3.3, 4.74), 'text': ' But to be quite honest with you,'}]
# end_2:  0:00:30.296720
# [{'timestamp': (0.0, 2.66), 'text': " I'm like, yeah, not bad."}, {'timestamp': (3.3, 4.74), 'text': ' But to be quite honest with you,'}]
# end_3:  0:00:01.189031
# Перевод на ru: "Да, неплохо".
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# end_4:  0:00:00.334034
# end_1:  0:00:00
# [{'timestamp': (0.0, 2.12), 'text': ' but to be quite honest with you'}, {'timestamp': (2.12, 4.28), 'text': " those are the last things I'm looking for"}, {'timestamp': (4.28, 5.14), 'text': ' the most important'}]
# end_2:  0:00:33.168819
# [{'timestamp': (0.0, 2.12), 'text': ' but to be quite honest with you'}, {'timestamp': (2.12, 4.28), 'text': " those are the last things I'm looking for"}, {'timestamp': (4.28, 5.14), 'text': ' the most important'}]
# end_3:  0:00:01.188606
# Перевод на ru: но быть с вами честным
# end_4:  0:00:00.409326
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 2.16), 'text': " Those are the last things I'm looking for."}, {'timestamp': (2.42, 3.46), 'text': ' The most important thing?'}, {'timestamp': (3.46, 5.46), 'text': ' Self-love.'}]
# end_2:  0:00:32.834370
# [{'timestamp': (0.0, 2.16), 'text': " Those are the last things I'm looking for."}, {'timestamp': (2.42, 3.46), 'text': ' The most important thing?'}, {'timestamp': (3.46, 5.46), 'text': ' Self-love.'}]
# end_3:  0:00:01.046566
# Это последнее, что я ищу.
# end_4:  0:00:00.548283
# end_1:  0:00:00
# [{'timestamp': (0.0, 1.36), 'text': ' The most important thing?'}, {'timestamp': (2.38, 3.54), 'text': ' Self-confidence.'}, {'timestamp': (4.24, 5.38), 'text': ' Without that confidence,'}]
# end_2:  0:00:29.084406
# [{'timestamp': (0.0, 1.36), 'text': ' The most important thing?'}, {'timestamp': (2.38, 3.54), 'text': ' Self-confidence.'}, {'timestamp': (4.24, 5.38), 'text': ' Without that confidence,'}]
# end_3:  0:00:00.951469
# Перевод на ru: Самая важная вещь?
# end_4:  0:00:00.383515
# end_1:  0:00:00.000748
# [{'timestamp': (0.0, 2.24), 'text': ' self-confidence.'}, {'timestamp': (2.9, 4.4), 'text': ' Without that skill,'}, {'timestamp': (4.58, 5.14), 'text': ' and I use the word'}]
# end_2:  0:00:29.314322
# [{'timestamp': (0.0, 2.24), 'text': ' self-confidence.'}, {'timestamp': (2.9, 4.4), 'text': ' Without that skill,'}, {'timestamp': (4.58, 5.14), 'text': ' and I use the word'}]
# end_3:  0:00:00.798397
# Перевод на ru: самоуверенность.
# end_4:  0:00:00.390316
# end_1:  0:00:00
# [{'timestamp': (0.0, 5.14), 'text': ' without that skill and i use the word skill intentionally without that'}]
# end_2:  0:00:26.049660
# end_1:  0:00:00
# [{'timestamp': (0.0, 5.14), 'text': ' without that skill and i use the word skill intentionally without that'}]
# end_2:  0:00:26.066879
# [{'timestamp': (0.0, 5.14), 'text': ' without that skill and i use the word skill intentionally without that'}]
# end_3:  0:00:01.923256
# Перевод на ru: без этого навыка и я намеренно использую слово "навык" без этого.
# end_4:  0:00:01.094071
# end_1:  0:00:00
# [{'timestamp': (0.0, 7.04), 'text': ' skill we are useless as a soccer player because when you lose'}]
# end_2:  0:00:26.351459
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 7.04), 'text': ' skill we are useless as a soccer player because when you lose'}]
# end_2:  0:00:26.269196
# [{'timestamp': (0.0, 7.04), 'text': ' skill we are useless as a soccer player because when you lose'}]
# end_3:  0:00:01.836688
# Перевод на ru: Навыки мы бесполезны как футболист, потому что когда вы проигрываете
# end_4:  0:00:01.138682
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 0.9), 'text': " We're done for."}, {'timestamp': (1.54, 3.78), 'text': ' I use the definition of self-confidence to be'}, {'timestamp': (3.78, 5.16), 'text': ' the ability...'}]
# end_2:  0:00:32.174691
# [{'timestamp': (0.0, 0.9), 'text': " We're done for."}, {'timestamp': (1.54, 3.78), 'text': ' I use the definition of self-confidence to be'}, {'timestamp': (3.78, 5.16), 'text': ' the ability...'}]
# end_3:  0:00:00.876819
# Мы закончили.
# end_4:  0:00:00.345572
# end_1:  0:00:00
# [{'timestamp': (0.0, 5.06), 'text': ' I use the definition of self-confidence to be the ability or the belief'}]
# end_2:  0:00:28.102957
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 5.06), 'text': ' I use the definition of self-confidence to be the ability or the belief'}]
# end_2:  0:00:28.061697
# [{'timestamp': (0.0, 5.06), 'text': ' I use the definition of self-confidence to be the ability or the belief'}]
# end_3:  0:00:01.514791
# Перевод на ru: Я использую определение уверенности в себе как способность или вера
# end_4:  0:00:01.082591
# end_1:  0:00:00
# [{'timestamp': (0.0, 1.98), 'text': ' to believe in yourself'}, {'timestamp': (1.98, 4.28), 'text': ' to accomplish any task'}, {'timestamp': (4.28, 5.12), 'text': ' no matter the'}]
# end_2:  0:00:27.969276
# [{'timestamp': (0.0, 1.98), 'text': ' to believe in yourself'}, {'timestamp': (1.98, 4.28), 'text': ' to accomplish any task'}, {'timestamp': (4.28, 5.12), 'text': ' no matter the'}]
# end_3:  0:00:00.735038
# Перевод на ru: верить в себя
# end_4:  0:00:00.295170
# end_1:  0:00:00
# [{'timestamp': (0.0, 5.0), 'text': ' to accomplish any task, no matter the odds, no matter the difficulty.'}]
# end_2:  0:00:28.171883
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 5.0), 'text': ' to accomplish any task, no matter the odds, no matter the difficulty.'}]
# end_2:  0:00:28.027889
# [{'timestamp': (0.0, 5.0), 'text': ' to accomplish any task, no matter the odds, no matter the difficulty.'}]
# end_3:  0:00:01.349212
# Перевод на ru: выполнить любую задачу, независимо от шансов, независимо от трудностей.
# end_4:  0:00:01.352754
# end_1:  0:00:00.000752
# [{'timestamp': (0.0, 1.26), 'text': ' no matter the adversity.'}, {'timestamp': (1.84, 4.5), 'text': ' The belief that you can accomplish it.'}]
# end_2:  0:00:28.175478
# [{'timestamp': (0.0, 1.26), 'text': ' no matter the adversity.'}, {'timestamp': (1.84, 4.5), 'text': ' The belief that you can accomplish it.'}]
# end_3:  0:00:01.201146
# Перевод на ru: независимо от неприятностей.
# end_4:  0:00:00.549938
# end_1:  0:00:00
# [{'timestamp': (0.0, 3.3), 'text': ' the belief that you can accomplish it'}, {'timestamp': (3.3, 4.5), 'text': ' self-confidence'}]
# end_2:  0:00:26.468094
# [{'timestamp': (0.0, 3.3), 'text': ' the belief that you can accomplish it'}, {'timestamp': (3.3, 4.5), 'text': ' self-confidence'}]
# end_3:  0:00:01.188014
# Перевод на ru: вера в то, что вы сможете это сделать
# end_4:  0:00:00.628499
# end_1:  0:00:00
# [{'timestamp': (0.0, 1.26), 'text': ' self-confidence'}, {'timestamp': (1.26, 2.14), 'text': ' some of you are saying'}, {'timestamp': (2.14, 3.24), 'text': " great I don't have it"}, {'timestamp': (3.24, 3.8), 'text': " I'm so shy"}, {'timestamp': (3.8, 4.72), 'text': " I'll never do that"}, {'timestamp': (4.72, 4.98), 'text': " I'm not"}]
# end_2:  0:00:40.572887
# [{'timestamp': (0.0, 1.26), 'text': ' self-confidence'}, {'timestamp': (1.26, 2.14), 'text': ' some of you are saying'}, {'timestamp': (2.14, 3.24), 'text': " great I don't have it"}, {'timestamp': (3.24, 3.8), 'text': " I'm so shy"}, {'timestamp': (3.8, 4.72), 'text': " I'll never do that"}, {'timestamp': (4.72, 4.98), 'text': " I'm not"}]
# end_3:  0:00:00.731250
# Перевод на ru: самоуверенность
# end_4:  0:00:00.402750
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 3.5), 'text': " some of you are saying, great, I don't have it, I'm so shy, I'll never do good"}, {'timestamp': (3.5, 5.08), 'text': ' and you start'}]
# end_2:  0:00:36.050625
# [{'timestamp': (0.0, 3.5), 'text': " some of you are saying, great, I don't have it, I'm so shy, I'll never do good"}, {'timestamp': (3.5, 5.08), 'text': ' and you start'}]
# end_3:  0:00:02.983772
# Перевод на ru: некоторые из вас говорят: "Великолепно, у меня его нет, я так стесняюсь, я никогда не буду делать добро"
# end_4:  0:00:01.756285
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 3.0), 'text': ' and you start to drag all the way down here'}]
# end_2:  0:00:25.078985
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 3.0), 'text': ' and you start to drag all the way down here'}]
# end_2:  0:00:24.931570
# [{'timestamp': (0.0, 3.0), 'text': ' and you start to drag all the way down here'}]
# end_3:  0:00:01.255028
# Перевод на ru: и ты начинаешь таскать сюда весь путь
# end_4:  0:00:00.647306
# end_1:  0:00:00
# [{'timestamp': (0.0, 4.8), 'text': ' but I use the word skill because'}]
# end_2:  0:00:23.355923
# end_1:  0:00:00.000752
# [{'timestamp': (0.0, 4.8), 'text': ' but I use the word skill because'}]
# end_2:  0:00:24.577564
# [{'timestamp': (0.0, 4.8), 'text': ' but I use the word skill because'}]
# end_3:  0:00:01.435207
# Перевод на ru: но я использую слово "навык", потому что
# end_4:  0:00:00.641254
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 1.84), 'text': ' Because I believe it can be trained.'}, {'timestamp': (2.38, 4.2), 'text': " And I'll show you a couple of ways in which we do."}, {'timestamp': (4.52, 5.18), 'text': " Hopefully I won't..."}]
# end_2:  0:00:37.720325
# [{'timestamp': (0.0, 1.84), 'text': ' Because I believe it can be trained.'}, {'timestamp': (2.38, 4.2), 'text': " And I'll show you a couple of ways in which we do."}, {'timestamp': (4.52, 5.18), 'text': " Hopefully I won't..."}]
# end_3:  0:00:01.507406
# Перевод на ru: Потому что я верю, что его можно тренировать.
# end_4:  0:00:00.741051
# end_1:  0:00:00
# [{'timestamp': (0.0, 2.4), 'text': " and I'll show you a couple of ways in which we do."}, {'timestamp': (2.74, 3.94), 'text': " Hopefully I won't run out of time."}, {'timestamp': (4.02, 4.98), 'text': " I don't use any slides."}]
# end_2:  0:00:40.648747
# [{'timestamp': (0.0, 2.4), 'text': " and I'll show you a couple of ways in which we do."}, {'timestamp': (2.74, 3.94), 'text': " Hopefully I won't run out of time."}, {'timestamp': (4.02, 4.98), 'text': " I don't use any slides."}]
# end_3:  0:00:01.720546
# Перевод на ru: и я покажу вам пару способов, как мы это делаем.
# end_4:  0:00:00.818782
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 1.58), 'text': " hopefully I won't run out of time"}, {'timestamp': (1.58, 4.74), 'text': " I don't use any slides because my speech always goes here, here, here"}]
# end_2:  0:00:34.357682
# [{'timestamp': (0.0, 1.58), 'text': " hopefully I won't run out of time"}, {'timestamp': (1.58, 4.74), 'text': " I don't use any slides because my speech always goes here, here, here"}]
# end_3:  0:00:01.200283
# Перевод на ru: надеюсь, у меня не кончится время
# end_4:  0:00:00.589017
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 3.22), 'text': " I don't use any slides because my speech always goes here or here or here."}, {'timestamp': (3.5, 5.06), 'text': " So we'll see which way we get to."}]
# end_2:  0:00:35.889664
# [{'timestamp': (0.0, 3.22), 'text': " I don't use any slides because my speech always goes here or here or here."}, {'timestamp': (3.5, 5.06), 'text': " So we'll see which way we get to."}]
# end_3:  0:00:02.225250
# Перевод на ru: Я не использую слайды, потому что моя речь всегда идет здесь, здесь или здесь.
# end_4:  0:00:01.258009
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 1.88), 'text': " so we'll see which way we get to."}, {'timestamp': (2.54, 4.38), 'text': ' The easiest way to build self-confidence.'}]
# end_2:  0:00:31.109821
# [{'timestamp': (0.0, 1.88), 'text': " so we'll see which way we get to."}, {'timestamp': (2.54, 4.38), 'text': ' The easiest way to build self-confidence.'}]
# end_3:  0:00:01.438810
# Переведем на ru: посмотрим, как мы доберемся.
# end_4:  0:00:00.747004
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 2.52), 'text': ' The easiest way to build self-confidence.'}, {'timestamp': (2.52, 3.84), 'text': " There's no magic button."}, {'timestamp': (3.84, 5.04), 'text': " I can't say this."}]
# end_2:  0:00:33.458692
# [{'timestamp': (0.0, 2.52), 'text': ' The easiest way to build self-confidence.'}, {'timestamp': (2.52, 3.84), 'text': " There's no magic button."}, {'timestamp': (3.84, 5.04), 'text': " I can't say this."}]
# end_3:  0:00:01.202249
# Перевод на ru: Самый простой способ укрепить уверенность в себе.
# end_4:  0:00:00.792751
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 5.12), 'text': " There's no magic button. I can't say, hey, this plane is going down. Who can fly it? Put your hand up. I can't!"}]
# end_2:  0:00:38.234381
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 5.12), 'text': " There's no magic button. I can't say, hey, this plane is going down. Who can fly it? Put your hand up. I can't!"}]
# end_2:  0:00:38.167210
# [{'timestamp': (0.0, 5.12), 'text': " There's no magic button. I can't say, hey, this plane is going down. Who can fly it? Put your hand up. I can't!"}]
# end_3:  0:00:03.919499
# Перевод на ru: нет волшебной кнопки. Я не могу сказать, эй, этот самолёт падает. Кто может управлять им? Поднимите руку. Я не могу!
# end_4:  0:00:02.303820
# end_1:  0:00:00.001499
# [{'timestamp': (0.0, 2.0), 'text': " and I'm confident"}, {'timestamp': (3.76, 5.76), 'text': ' repetition'}]
# end_2:  0:00:23.222919
# [{'timestamp': (0.0, 2.0), 'text': " and I'm confident"}, {'timestamp': (3.76, 5.76), 'text': ' repetition'}]
# end_3:  0:00:00.815769
# Перевод на ru: и я уверен в себе
# end_4:  0:00:00.375002
# end_1:  0:00:00.002260
# [{'timestamp': (0.0, 4.6), 'text': ' Repetition, repetition, repetition.'}]
# end_2:  0:00:23.973266
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 4.6), 'text': ' Repetition, repetition, repetition.'}]
# end_2:  0:00:23.665716
# [{'timestamp': (0.0, 4.6), 'text': ' Repetition, repetition, repetition.'}]
# end_3:  0:00:01.119025
# Перевод на ru: Повторение, повторение, повторение.
# end_4:  0:00:00.648750
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 4.4), 'text': ' right? what does Malcolm Gladwell call it? the 10,000 hour rule?'}, {'timestamp': (4.4, 5.0), 'text': " there's no"}]
# end_2:  0:00:31.848272
# [{'timestamp': (0.0, 4.4), 'text': ' right? what does Malcolm Gladwell call it? the 10,000 hour rule?'}, {'timestamp': (4.4, 5.0), 'text': " there's no"}]
# end_3:  0:00:02.037636
# Перевод на ru: правильно? Как Малкольм Гладвелл называет это правилом 10 000 часов?
# end_4:  0:00:01.006328
# end_1:  0:00:00.000748
# [{'timestamp': (0.0, 4.12), 'text': " There's no magic button. I recruited a goalie from Columbia, South America one year."}]
# end_2:  0:00:30.022838
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 4.12), 'text': " There's no magic button. I recruited a goalie from Columbia, South America one year."}]
# end_2:  0:00:30.027441
# [{'timestamp': (0.0, 4.12), 'text': " There's no magic button. I recruited a goalie from Columbia, South America one year."}]
# end_3:  0:00:02.928557
# Перевод на ru: нет волшебной кнопки, я завербовал вратаря из Колумбии, Южная Америка.
# end_4:  0:00:01.391222
# end_1:  0:00:00.001500
# [{'timestamp': (0.0, 2.66), 'text': ' Big tall 6 foot 3 man'}, {'timestamp': (2.66, 4.98), 'text': ' You know, he had hands like'}]
# end_2:  0:00:27.700911
# [{'timestamp': (0.0, 2.66), 'text': ' Big tall 6 foot 3 man'}, {'timestamp': (2.66, 4.98), 'text': ' You know, he had hands like'}]
# end_3:  0:00:01.115733
# Перевод на ru: большой рост 6 футов 3 человек
# end_4:  0:00:00.534750
# end_1:  0:00:00.001500
# [{'timestamp': (0.0, 4.0), 'text': ' You know, he had hands like stone. I thought he was like Flipper.'}, {'timestamp': (4.0, 6.0), 'text': " Every time I throw him the ball, he's like..."}]
# end_2:  0:00:37.626670
# [{'timestamp': (0.0, 4.0), 'text': ' You know, he had hands like stone. I thought he was like Flipper.'}, {'timestamp': (4.0, 6.0), 'text': " Every time I throw him the ball, he's like..."}]
# end_3:  0:00:02.127017
# Переведи на ru: у него были руки, как камень, я думала, он был как Флиппер.
# end_4:  0:00:01.172602
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 2.6), 'text': ' Every time I throw him the ball, it just dumps, dumps onto the ground.'}, {'timestamp': (2.8, 4.34), 'text': " It's like, oh my god, we're in trouble."}]
# end_2:  0:00:39.165426
# [{'timestamp': (0.0, 2.6), 'text': ' Every time I throw him the ball, it just dumps, dumps onto the ground.'}, {'timestamp': (2.8, 4.34), 'text': " It's like, oh my god, we're in trouble."}]
# end_3:  0:00:01.973094
# Каждый раз, когда я бросаю ему мяч, он просто сбрасывается, сбрасывается на землю.
# end_4:  0:00:01.416834
# end_1:  0:00:00.003751
# [{'timestamp': (0.0, 1.8), 'text': " I was like, oh my god, we're in trouble."}, {'timestamp': (2.6, 3.54), 'text': ' Simple solution.'}, {'timestamp': (3.82, 5.06), 'text': ' Get to the wall, kick a ball.'}]
# end_2:  0:00:35.800147
# [{'timestamp': (0.0, 1.8), 'text': " I was like, oh my god, we're in trouble."}, {'timestamp': (2.6, 3.54), 'text': ' Simple solution.'}, {'timestamp': (3.82, 5.06), 'text': ' Get to the wall, kick a ball.'}]
# end_3:  0:00:01.188751
# Перевод на ru: "О боже, у нас проблемы".
# end_4:  0:00:00.385500
# end_1:  0:00:00.001500
# [{'timestamp': (0.0, 1.76), 'text': ' simple solution'}, {'timestamp': (1.76, 4.34), 'text': ' get to the wall, kick the ball against the wall and catch it'}]
# end_2:  0:00:29.288230
# [{'timestamp': (0.0, 1.76), 'text': ' simple solution'}, {'timestamp': (1.76, 4.34), 'text': ' get to the wall, kick the ball against the wall and catch it'}]
# end_3:  0:00:00.669032
# перевод на ru: простое решение
# end_4:  0:00:00.587232
# end_1:  0:00:00.000756
# [{'timestamp': (0.0, 2.58), 'text': ' Get to the wall, kick a ball against the wall and catch it.'}, {'timestamp': (2.68, 4.18), 'text': ' Kick the ball against the wall and catch it.'}, {'timestamp': (4.46, 5.0), 'text': ' His goal...'}]
# end_2:  0:00:37.421566
# [{'timestamp': (0.0, 2.58), 'text': ' Get to the wall, kick a ball against the wall and catch it.'}, {'timestamp': (2.68, 4.18), 'text': ' Kick the ball against the wall and catch it.'}, {'timestamp': (4.46, 5.0), 'text': ' His goal...'}]
# end_3:  0:00:02.384522
# Переведи на ru: подойди к стене, ударь мячом об стену и поймай его.
# end_4:  0:00:01.051755
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 1.62), 'text': ' kick the ball against the wall and catch it.'}, {'timestamp': (1.96, 4.8), 'text': ' His goal was 350 a day for 8 months.'}]
# end_2:  0:00:31.533196
# [{'timestamp': (0.0, 1.62), 'text': ' kick the ball against the wall and catch it.'}, {'timestamp': (1.96, 4.8), 'text': ' His goal was 350 a day for 8 months.'}]
# end_3:  0:00:01.775112
# Перевод на ru: ударить мяч по стене и поймать его.
# end_4:  0:00:00.687000
# end_1:  0:00:00.001500
# [{'timestamp': (0.0, 3.22), 'text': ' His goal was 350 a day for eight months.'}, {'timestamp': (3.78, 4.66), 'text': ' He came back.'}]
# end_2:  0:00:28.541457
# [{'timestamp': (0.0, 3.22), 'text': ' His goal was 350 a day for eight months.'}, {'timestamp': (3.78, 4.66), 'text': ' He came back.'}]
# end_3:  0:00:00.964501
# Его цель была 350 в день в течение восьми месяцев.
# end_4:  0:00:00.761250
# end_1:  0:00:00.001501
# [{'timestamp': (0.0, 5.06), 'text': ' he came back his hands were calloused the moisture on his hands were literally'}]
# end_2:  0:00:28.012696
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 5.06), 'text': ' he came back his hands were calloused the moisture on his hands were literally'}]
# end_2:  0:00:27.992061
# [{'timestamp': (0.0, 5.06), 'text': ' he came back his hands were calloused the moisture on his hands were literally'}]
# end_3:  0:00:02.464269
# Переводит на ru: он вернулся к рукам, и его руки были злыми, влагою на его руках была буквально
# end_4:  0:00:01.546128
# end_1:  0:00:00.000738
# [{'timestamp': (0.0, 5.1), 'text': ' gone, he is now playing in Europe. Magic? No. Repetition? Repetition?'}]
# end_2:  0:00:31.333228
# end_1:  0:00:00.001501
# [{'timestamp': (0.0, 5.1), 'text': ' gone, he is now playing in Europe. Magic? No. Repetition? Repetition?'}]
# end_2:  0:00:31.117251
# [{'timestamp': (0.0, 5.1), 'text': ' gone, he is now playing in Europe. Magic? No. Repetition? Repetition?'}]
# end_3:  0:00:02.039510
# Перевод на ru: ушел, теперь играет в Европе. Магия? Нет. Повторение? Повторение?
# end_4:  0:00:01.471535
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 5.0), 'text': " repetition. The problem is we expect to be self-confident, but we can't be."}]
# end_2:  0:00:30.725274
# end_1:  0:00:00.001500
# [{'timestamp': (0.0, 5.0), 'text': " repetition. The problem is we expect to be self-confident, but we can't be."}]
# end_2:  0:00:30.681711
# [{'timestamp': (0.0, 5.0), 'text': " repetition. The problem is we expect to be self-confident, but we can't be."}]
# end_3:  0:00:01.692000
# Проблема в том, что мы должны быть уверены в себе, но мы не можем.
# end_4:  0:00:01.068155
# end_1:  0:00:00.000749
# [{'timestamp': (0.0, 4.94), 'text': " unless the skill or the task we're doing is not novel, is not new to us."}]
# end_2:  0:00:30.119262
# end_1:  0:00:00.000755
# [{'timestamp': (0.0, 4.94), 'text': " unless the skill or the task we're doing is not novel, is not new to us."}]
# end_2:  0:00:29.921578
# [{'timestamp': (0.0, 4.94), 'text': " unless the skill or the task we're doing is not novel, is not new to us."}]
# end_3:  0:00:02.036036
# Перевод на ru: если только навыки или задачи, которые мы выполняем, не новы, не новы для нас.
# end_4:  0:00:01.377073
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 5.0), 'text': " We want to be in a situation where we've had so much pressure in that."}]
# end_2:  0:00:28.809355
# end_1:  0:00:00.000752
# [{'timestamp': (0.0, 5.0), 'text': " We want to be in a situation where we've had so much pressure in that."}]
# end_2:  0:00:28.687262
# [{'timestamp': (0.0, 5.0), 'text': " We want to be in a situation where we've had so much pressure in that."}]
# end_3:  0:00:01.199250
# Мы хотим оказаться в ситуации, когда на нас было так много давления.
# end_4:  0:00:01.067083
# end_1:  0:00:00.000760
# [{'timestamp': (0.0, 2.06), 'text': ' And what I mean because pressure builds diamonds?'}, {'timestamp': (2.4, 5.1), 'text': ' We want to be in a situation where, hey...'}]
# end_2:  0:00:31.847390
# [{'timestamp': (0.0, 2.06), 'text': ' And what I mean because pressure builds diamonds?'}, {'timestamp': (2.4, 5.1), 'text': ' We want to be in a situation where, hey...'}]
# end_3:  0:00:01.446310
# Перевод на ru: Что я имею в виду, потому что давление создает алмазы?
# end_4:  0:00:00.884254
# end_1:  0:00:00.001499
# [{'timestamp': (0.0, 4.36), 'text': " We want to be in a situation where, hey, I've done this a thousand times."}]
# end_2:  0:00:30.081950
# end_1:  0:00:00.001501
# [{'timestamp': (0.0, 4.36), 'text': " We want to be in a situation where, hey, I've done this a thousand times."}]
# end_2:  0:00:29.978579
# [{'timestamp': (0.0, 4.36), 'text': " We want to be in a situation where, hey, I've done this a thousand times."}]
# end_3:  0:00:01.445779
# Мы хотим оказаться в ситуации, когда я делал это тысячу раз.
# end_4:  0:00:01.031032
# end_1:  0:00:00.000750
# [{'timestamp': (0.0, 2.56), 'text': ' I did my speech, I practiced in front of the mirror'}, {'timestamp': (2.56, 3.76), 'text': ' da da da da da da da da'}, {'timestamp': (3.76, 4.88), 'text': " hey, I'm sounding good"}]
# end_2:  0:00:36.270080
# [{'timestamp': (0.0, 2.56), 'text': ' I did my speech, I practiced in front of the mirror'}, {'timestamp': (2.56, 3.76), 'text': ' da da da da da da da da'}, {'timestamp': (3.76, 4.88), 'text': " hey, I'm sounding good"}]
# end_3:  0:00:01.603737
# Перевод на ru: Я произнёс речь, тренировался перед зеркалом
# end_4:  0:00:00.829255
# end_1:  0:00:00.000751
# [{'timestamp': (0.0, 1.26), 'text': ' da da da da da da da da'}, {'timestamp': (1.26, 2.3), 'text': " hey, I'm sounding good"}, {'timestamp': (2.3, 5.06), 'text': ' and then I ran in front of my kids and my wife'}]
# end_2:  0:00:36.501564
# [{'timestamp': (0.0, 1.26), 'text': ' da da da da da da da da'}, {'timestamp': (1.26, 2.3), 'text': " hey, I'm sounding good"}, {'timestamp': (2.3, 5.06), 'text': ' and then I ran in front of my kids and my wife'}]
# end_3:  0:00:04.427058
# Перевод на ru: da da da da da da da da da da da da da
# end_1:  0:00:00.001501
# [{'timestamp': (0.0, 1.08), 'text': " Hey, I'm sounding good."}, {'timestamp': (1.44, 3.92), 'text': ' And then I ran in front of my kids and my wife.'}, {'timestamp': (4.3, 5.02), 'text': ' I was like, oh my gosh.'}]
# end_2:  0:00:37.620481
# [{'timestamp': (0.0, 1.08), 'text': " Hey, I'm sounding good."}, {'timestamp': (1.44, 3.92), 'text': ' And then I ran in front of my kids and my wife.'}, {'timestamp': (4.3, 5.02), 'text': ' I was like, oh my gosh.'}]
# end_3:  0:00:00.664500
# Эй, звучит неплохо.
# end_4:  0:00:00.412382
# end_1:  0:00:00.000761
# [{'timestamp': (0.0, 2.9), 'text': ' and then I ran in front of my kids and my wife.'}, {'timestamp': (3.28, 4.7), 'text': ' I was like, oh my gosh, I got a little nervous.'}]
# end_2:  0:00:36.093040
# [{'timestamp': (0.0, 2.9), 'text': ' and then I ran in front of my kids and my wife.'}, {'timestamp': (3.28, 4.7), 'text': ' I was like, oh my gosh, I got a little nervous.'}]
# end_3:  0:00:01.623775
# Переведи на ru: а потом я побежала перед своими детьми и женой.
# end_4:  0:00:01.055619
# end_1:  0:00:00.000759
# [{'timestamp': (0.0, 1.82), 'text': ' I was like, oh my gosh, I got a little nervous.'}, {'timestamp': (1.98, 4.54), 'text': " And then you get in front of the Glen Gould, oh my goodness, I'm a little more nervous."}]
# end_2:  0:00:52.370687
# [{'timestamp': (0.0, 1.82), 'text': ' I was like, oh my gosh, I got a little nervous.'}, {'timestamp': (1.98, 4.54), 'text': " And then you get in front of the Glen Gould, oh my goodness, I'm a little more nervous."}]
# end_3:  0:00:01.334658
# Я такой: "Боже мой, я немного нервничал.
# end_4:  0:00:00.800997
# end_1:  0:00:00.006001
# [{'timestamp': (0.0, 1.26), 'text': ' Then you get in front of the Glen Gould.'}, {'timestamp': (1.36, 2.78), 'text': " Oh my goodness, I'm a little more nervous."}, {'timestamp': (3.28, 5.0), 'text': ' By the time I get to the ACG...'}]
# end_2:  0:00:40.825364
# [{'timestamp': (0.0, 1.26), 'text': ' Then you get in front of the Glen Gould.'}, {'timestamp': (1.36, 2.78), 'text': " Oh my goodness, I'm a little more nervous."}, {'timestamp': (3.28, 5.0), 'text': ' By the time I get to the ACG...'}]
# end_3:  0:00:01.556476
# Переведи на ru: тогда ты встанешь перед Глен Гулдом.
# end_4:  0:00:00.776512
# end_1:  0:00:00.001499
# [{'timestamp': (0.0, 1.56), 'text': " Oh my goodness, I'm a little more nervous."}, {'timestamp': (2.06, 5.16), 'text': " By the time I get to the ACG, we're at 2,500 people."}]
# end_2:  0:00:37.546510
# [{'timestamp': (0.0, 1.56), 'text': " Oh my goodness, I'm a little more nervous."}, {'timestamp': (2.06, 5.16), 'text': " By the time I get to the ACG, we're at 2,500 people."}]
# end_3:  0:00:00.892516
# О боже, я немного нервничаю.
# end_4:  0:00:00.562500
# end_1:  0:00:00.001500
# [{'timestamp': (0.0, 5.0), 'text': " By the time I get to the ACG, where 2500 people can't say anymore..."}]
# end_2:  0:00:30.532255
# end_1:  0:00:00.001500
# [{'timestamp': (0.0, 5.0), 'text': " By the time I get to the ACG, where 2500 people can't say anymore..."}]
# end_2:  0:00:30.430712
# [{'timestamp': (0.0, 5.0), 'text': " By the time I get to the ACG, where 2500 people can't say anymore..."}]
# end_3:  0:00:01.980027
# К тому времени, как я доберусь до АКГ, где 2500 человек больше не могут говорить...
# end_4:  0:00:01.211254
# end_1:  0:00:00.001503
# [{'timestamp': (0.0, 2.46), 'text': ' Right? 2,500 people.'}, {'timestamp': (3.0, 4.98), 'text': ' Where 2,500 people are there.'}]
# end_2:  0:00:29.529750
# [{'timestamp': (0.0, 2.46), 'text': ' Right? 2,500 people.'}, {'timestamp': (3.0, 4.98), 'text': ' Where 2,500 people are there.'}]
# end_3:  0:00:00.756000
# 2 500 человек.
# end_4:  0:00:00.249225
# end_1:  0:00:00.001499
# [{'timestamp': (0.0, 2.54), 'text': ' where 2,500 people are there,'}, {'timestamp': (2.8, 5.14), 'text': " I won't have a single ounce of nervousness."}]
# end_2:  0:00:31.611048
# [{'timestamp': (0.0, 2.54), 'text': ' where 2,500 people are there,'}, {'timestamp': (2.8, 5.14), 'text': " I won't have a single ounce of nervousness."}]
# end_3:  0:00:00.896766
# перевод на ru: где 2 500 человек,
# end_4:  0:00:00.481499
# end_1:  0:00:00.002249
